# %% [markdown]
# <h2>Simple Regression Dataset - Linear Regression vs XGBoost</h2>
#
# Model is trained with XGBoost installed in notebook instance
#
# In the later examples, we will train using SageMaker's XGBoost algorithm.
#
# Training on SageMaker takes several minutes (even for simple dataset).
#
# If algorithm is supported on Python, we will try them locally on notebook instance
#
# This allows us to quickly learn an algorithm, understand tuning options and then finally train on SageMaker Cloud
#
# In this exercise, let's compare XGBoost and Linear Regression for simple regression dataset

# %%
# Install xgboost in notebook instance.
#### Command to install xgboost
# !pip install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-2.0.3-py3-none-manylinux2014_x86_64.whl.metadata (2.0 kB)
# Requirement already satisfied: numpy in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from xgboost) (1.22.4)
# Requirement already satisfied: scipy in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from xgboost) (1.11.3)
# Downloading xgboost-2.0.3-py3-none-manylinux2014_x86_64.whl (297.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.1/297.1 MB 1.2 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: xgboost
# Successfully installed xgboost-2.0.3

# %%
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error


# XGBoost 
import xgboost as xgb
# Linear Regression
from sklearn.linear_model import LinearRegression
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.0' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
# All data
df = pd.read_csv('linear_all.csv')

# %%
df.head()
# Out:
#    x          y
# 0  0  12.412275
# 1  1   9.691298
# 2  2  42.307712
# 3  3  20.479079
# 4  4  29.096098

# %%
plt.plot(df.x,df.y,label='Target')
plt.grid(True)
plt.xlabel('Input Feature')
plt.ylabel('Target')
plt.legend()
plt.title('Simple Regression Dataset')
plt.show()

# %%
# Let's load Training and Validation Datasets
train_file = 'linear_train.csv'
validation_file = 'linear_validation.csv'

# Specify the column names as the file does not have column header
df_train = pd.read_csv(train_file,names=['y','x'])
df_validation = pd.read_csv(validation_file,names=['y','x'])

# %%
df_train.head()
# Out:
#             y    x
# 0  425.457270   82
# 1  687.275162  134
# 2  554.643782  114
# 3  219.007382   42
# 4  560.269533  109

# %%
df_validation.head()
# Out:
#             y    x
# 0  342.264067   67
# 1   60.951235   11
# 2  315.592889   62
# 3  700.097979  137
# 4  535.676139  108

# %%
plt.scatter(df_train.x,df_train.y,label='Training',marker='.')
plt.scatter(df_validation.x,df_validation.y,label='Validation',marker='.')
plt.grid(True)
plt.xlabel('Input Feature')
plt.ylabel('Target')
plt.title('Simple Regression Dataset')
plt.legend()
plt.show()

# %%
X_train = df_train.iloc[:,1:] # Features: 1st column onwards 
y_train = df_train.iloc[:,0].ravel() # Target: 0th column

X_validation = df_validation.iloc[:,1:]
y_validation = df_validation.iloc[:,0].ravel()

# %%
# Create an instance of XGBoost Regressor
# XGBoost Training Parameter Reference: 
#   https://github.com/dmlc/xgboost/blob/master/doc/parameter.md
regressor = xgb.XGBRegressor()

# %%
# Default Options
regressor
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
# Train the model
# Provide Training Dataset and Validation Dataset
# XGBoost reports training and validation error
regressor.fit(X_train,y_train, eval_set = [(X_train, y_train), (X_validation, y_validation)])
# Out:
# [0]	validation_0-rmse:152.38658	validation_1-rmse:169.97121
# [1]	validation_0-rmse:110.60426	validation_1-rmse:125.07907
# [2]	validation_0-rmse:80.62687	validation_1-rmse:92.65117
# [3]	validation_0-rmse:58.98572	validation_1-rmse:68.42855
# [4]	validation_0-rmse:43.50380	validation_1-rmse:51.25514
# [5]	validation_0-rmse:32.31010	validation_1-rmse:39.23497
# [6]	validation_0-rmse:24.15492	validation_1-rmse:29.88069
# [7]	validation_0-rmse:18.22784	validation_1-rmse:23.33289
# [8]	validation_0-rmse:13.95016	validation_1-rmse:19.33846
# [9]	validation_0-rmse:10.82068	validation_1-rmse:16.67512
# [10]	validation_0-rmse:8.56789	validation_1-rmse:15.21995
# [11]	validation_0-rmse:6.96096	validation_1-rmse:14.58477
# [12]	validation_0-rmse:5.83143	validation_1-rmse:14.47457
# [13]	validation_0-rmse:5.03393	validation_1-rmse:14.47994
# [14]	validation_0-rmse:4.37533	validation_1-rmse:14.53170
# [15]	validation_0-rmse:3.89580	validation_1-rmse:14.64853
# [16]	validation_0-rmse:3.52665	validation_1-rmse:14.70181
# [17]	validation_0-rmse:3.23307	validation_1-rmse:14.89160
# [18]	validation_0-rmse:3.01489	validation_1-rmse:14.98792
# [19]	validation_0-rmse:2.80251	validation_1-rmse:14.96761
# [20]	validation_0-rmse:2.68303	validation_1-rmse:15.04687
# [21]	validation_0-rmse:2.54967	validation_1-rmse:15.05609
# [22]	validation_0-rmse:2.44049	validation_1-rmse:15.11751
# [23]	validation_0-rmse:2.36643	validation_1-rmse:15.22980
# [24]	validation_0-rmse:2.30278	validation_1-rmse:15.32645
# [25]	validation_0-rmse:2.23730	validation_1-rmse:15.35202
# [26]	validation_0-rmse:2.13384	validation_1-rmse:15.37801
# [27]	validation_0-rmse:2.11786	validation_1-rmse:15.40404
# [28]	validation_0-rmse:2.09712	validation_1-rmse:15.40176
# [29]	validation_0-rmse:2.06862	validation_1-rmse:15.45125
# [30]	validation_0-rmse:2.03307	validation_1-rmse:15.47503
# [31]	validation_0-rmse:1.97257	validation_1-rmse:15.48490
# [32]	validation_0-rmse:1.95557	validation_1-rmse:15.50850
# [33]	validation_0-rmse:1.89638	validation_1-rmse:15.50905
# [34]	validation_0-rmse:1.80728	validation_1-rmse:15.52113
# [35]	validation_0-rmse:1.74414	validation_1-rmse:15.54003
# [36]	validation_0-rmse:1.71503	validation_1-rmse:15.53237
# [37]	validation_0-rmse:1.66995	validation_1-rmse:15.53124
# [38]	validation_0-rmse:1.61454	validation_1-rmse:15.57967
# [39]	validation_0-rmse:1.60153	validation_1-rmse:15.60034
# [40]	validation_0-rmse:1.57795	validation_1-rmse:15.59076
# [41]	validation_0-rmse:1.54462	validation_1-rmse:15.59041
# [42]	validation_0-rmse:1.53542	validation_1-rmse:15.59929
# [43]	validation_0-rmse:1.46675	validation_1-rmse:15.61596
# [44]	validation_0-rmse:1.45522	validation_1-rmse:15.60897
# [45]	validation_0-rmse:1.43911	validation_1-rmse:15.60344
# [46]	validation_0-rmse:1.37554	validation_1-rmse:15.62282
# [47]	validation_0-rmse:1.34917	validation_1-rmse:15.62299
# [48]	validation_0-rmse:1.33474	validation_1-rmse:15.61851
# [49]	validation_0-rmse:1.28970	validation_1-rmse:15.65959
# [50]	validation_0-rmse:1.22826	validation_1-rmse:15.67813
# [51]	validation_0-rmse:1.18227	validation_1-rmse:15.68561
# [52]	validation_0-rmse:1.14393	validation_1-rmse:15.68275
# [53]	validation_0-rmse:1.09776	validation_1-rmse:15.72521
# [54]	validation_0-rmse:1.06588	validation_1-rmse:15.75341
# [55]	validation_0-rmse:1.04165	validation_1-rmse:15.76523
# [56]	validation_0-rmse:1.03564	validation_1-rmse:15.77365
# [57]	validation_0-rmse:1.01834	validation_1-rmse:15.77038
# [58]	validation_0-rmse:0.98644	validation_1-rmse:15.80632
# [59]	validation_0-rmse:0.95835	validation_1-rmse:15.83601
# [60]	validation_0-rmse:0.90048	validation_1-rmse:15.84941
# [61]	validation_0-rmse:0.88639	validation_1-rmse:15.84629
# [62]	validation_0-rmse:0.86399	validation_1-rmse:15.84685
# [63]	validation_0-rmse:0.82386	validation_1-rmse:15.85676
# [64]	validation_0-rmse:0.78720	validation_1-rmse:15.86657
# [65]	validation_0-rmse:0.77557	validation_1-rmse:15.86670
# [66]	validation_0-rmse:0.76974	validation_1-rmse:15.87389
# [67]	validation_0-rmse:0.74538	validation_1-rmse:15.89829
# [68]	validation_0-rmse:0.73658	validation_1-rmse:15.89659
# [69]	validation_0-rmse:0.72110	validation_1-rmse:15.89374
# [70]	validation_0-rmse:0.68994	validation_1-rmse:15.90253
# [71]	validation_0-rmse:0.66401	validation_1-rmse:15.91518
# [72]	validation_0-rmse:0.64117	validation_1-rmse:15.91901
# [73]	validation_0-rmse:0.62962	validation_1-rmse:15.91422
# [74]	validation_0-rmse:0.61600	validation_1-rmse:15.91747
# [75]	validation_0-rmse:0.59409	validation_1-rmse:15.93942
# [76]	validation_0-rmse:0.57764	validation_1-rmse:15.94805
# [77]	validation_0-rmse:0.55938	validation_1-rmse:15.95141
# [78]	validation_0-rmse:0.54880	validation_1-rmse:15.94717
# [79]	validation_0-rmse:0.52853	validation_1-rmse:15.96562
# [80]	validation_0-rmse:0.52243	validation_1-rmse:15.97125
# [81]	validation_0-rmse:0.51378	validation_1-rmse:15.97138
# [82]	validation_0-rmse:0.49917	validation_1-rmse:15.97152
# [83]	validation_0-rmse:0.48319	validation_1-rmse:15.97962
# [84]	validation_0-rmse:0.47439	validation_1-rmse:15.97603
# [85]	validation_0-rmse:0.46460	validation_1-rmse:15.97951
# [86]	validation_0-rmse:0.44769	validation_1-rmse:15.98821
# [87]	validation_0-rmse:0.43566	validation_1-rmse:15.99205
# [88]	validation_0-rmse:0.42488	validation_1-rmse:15.99794
# [89]	validation_0-rmse:0.41546	validation_1-rmse:15.99529
# [90]	validation_0-rmse:0.40437	validation_1-rmse:15.99512
# [91]	validation_0-rmse:0.40003	validation_1-rmse:15.99918
# [92]	validation_0-rmse:0.38935	validation_1-rmse:16.00152
# [93]	validation_0-rmse:0.37598	validation_1-rmse:16.01610
# [94]	validation_0-rmse:0.36273	validation_1-rmse:16.02470
# [95]	validation_0-rmse:0.35663	validation_1-rmse:16.02220
# [96]	validation_0-rmse:0.35055	validation_1-rmse:16.02116
# [97]	validation_0-rmse:0.34694	validation_1-rmse:16.02467
# [98]	validation_0-rmse:0.33547	validation_1-rmse:16.02993
# [99]	validation_0-rmse:0.32548	validation_1-rmse:16.03379
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
# Get the Training RMSE and Evaluation RMSE
eval_result = regressor.evals_result()

# %%
eval_result
# Out:
# {'validation_0': OrderedDict([('rmse',
#                [152.38658189636348,
#                 110.60426316761894,
#                 80.62687156369749,
#                 58.98572125572891,
#                 43.50380468915531,
#                 32.310097016715915,
#                 24.154916976733546,
#                 18.22783616316385,
#                 13.950162786366084,
#                 10.820676031571901,
#                 8.567890330837503,
#                 6.96096440635048,
#                 5.831428970772782,
#                 5.03392787382575,
#                 4.375331825041368,
#                 3.8958039089525704,
#                 3.52664755793328,
#                 3.2330671971428737,
#                 3.0148877985870404,
#                 2.802511760954399,
#                 2.683025050683944,
#                 2.549671692142712,
#                 2.440490476020773,
#                 2.366434340414166,
#                 2.302781863751638,
#                 2.2373047625143103,
#                 2.133841912362906,
#                 2.1178612891967936,
#                 2.0971230385368727,
#                 2.068620889544674,
#                 2.033074508896731,
#                 1.9725743064453445,
#                 1.9555662404458238,
#                 1.8963805506574176,
#                 1.8072832947548956,
#                 1.7441383514339641,
#                 1.715033883572755,
#                 1.6699464300209863,
#                 1.614541708696073,
#                 1.601530595593447,
#                 1.5779485106671371,
#                 1.5446241994387209,
#                 1.5354155085446988,
#                 1.4667494750423329,
#                 1.45521536643443,
#                 1.439105582576199,
#                 1.3755385177690713,
#                 1.34917025381534,
#                 1.334740971002071,
#                 1.2897042103242509,
#                 1.2282572115089718,
#                 1.1822742416505112,
#                 1.143927657294391,
#                 1.0977640542502791,
#                 1.0658841060919437,
#                 1.0416508805265208,
#                 1.0356366095907221,
#                 1.0183359229841062,
#                 0.9864447175659147,
#                 0.9583534086191569,
#                 0.9004764400782814,
#                 0.8863874594337009,
#                 0.8639869490721365,
#                 0.8238640718312501,
#                 0.7872000425934095,
#                 0.7755695909321326,
#                 0.769735247903486,
#                 0.7453772290440243,
#                 0.7365787068158569,
#                 0.7211006339779594,
#                 0.6899385142996115,
#                 0.66400543103573,
#                 0.6411657150271589,
#                 0.6296172973321421,
#                 0.6160017981561174,
#                 0.5940894297273619,
#                 0.5776395187022927,
#                 0.5593848861944684,
#                 0.5488040968952648,
#                 0.5285272394494489,
#                 0.522427039772038,
#                 0.5137847170082859,
#                 0.4991713885157576,
#                 0.48318840734529056,
#                 0.47439280420178725,
#                 0.4646003530723695,
#                 0.4476944817110913,
#                 0.4356590913260994,
#                 0.4248759692879835,
#                 0.4154597547546152,
#                 0.404365314941606,
#                 0.4000276058993242,
#                 0.38934620083765625,
#                 0.3759759933854268,
#                 0.36273110323752883,
#                 0.35663353524506286,
#                 0.3505468059744784,
#                 0.3469352934986735,
#                 0.33547203147670024,
#                 0.3254819879639741])]),
#  'validation_1': OrderedDict([('rmse',
#                [169.9712107896138,
#                 125.07907188995894,
#                 92.65117457217663,
#                 68.42855034951918,
#                 51.25514493016483,
#                 39.234971476850596,
#                 29.88069371016568,
#                 23.332893616756518,
#                 19.338457492118124,
#                 16.675115216649246,
#                 15.219950876283745,
#                 14.584772419681226,
#                 14.474566052524601,
#                 14.479939388380597,
#                 14.531695978062302,
#                 14.648525602536342,
#                 14.70180844222136,
#                 14.89160202177241,
#                 14.987923376750492,
#                 14.967605783571077,
#                 15.046866977157828,
#                 15.056093076253847,
#                 15.11750847135377,
#                 15.229796207828645,
#                 15.326446053654395,
#                 15.352017121279635,
#                 15.378006846188441,
#                 15.404044840377761,
#                 15.40175876029486,
#                 15.451251028886837,
#                 15.475034773503811,
#                 15.484901577361978,
#                 15.508495452518888,
#                 15.509052905989,
#                 15.521127065912953,
#                 15.540032358399241,
#                 15.532371389702583,
#                 15.531238546533539,
#                 15.579667876790255,
#                 15.600335047944284,
#                 15.590761816566358,
#                 15.590410649984317,
#                 15.599286304283677,
#                 15.615964215303872,
#                 15.608969365062622,
#                 15.603436710881622,
#                 15.622819175786477,
#                 15.62298797047568,
#                 15.618510882906524,
#                 15.659594416883317,
#                 15.678134846805671,
#                 15.685610117733539,
#                 15.682751546716608,
#                 15.725214558652674,
#                 15.75340561048548,
#                 15.765233280840823,
#                 15.773652981473493,
#                 15.77038433560388,
#                 15.806324596917934,
#                 15.836013171285927,
#                 15.849412510902114,
#                 15.846290560296655,
#                 15.846853261489015,
#                 15.856761925468714,
#                 15.86656920298301,
#                 15.866699455488058,
#                 15.873894887519917,
#                 15.898290182655296,
#                 15.896593090610041,
#                 15.893741508077348,
#                 15.902531599320401,
#                 15.9151808048284,
#                 15.919008536476166,
#                 15.914217498085655,
#                 15.91746828594999,
#                 15.939419791078956,
#                 15.948053600442654,
#                 15.951405927491857,
#                 15.947165029062734,
#                 15.96562195461134,
#                 15.971254026755336,
#                 15.971377659630127,
#                 15.9715218587606,
#                 15.979621518370204,
#                 15.976025338608231,
#                 15.979514847138494,
#                 15.988205323964682,
#                 15.992048675993889,
#                 15.997943981387607,
#                 15.995294017329142,
#                 15.99512012932793,
#                 15.999179867787133,
#                 16.001515198300673,
#                 16.016097910817628,
#                 16.024697474066368,
#                 16.022203999702857,
#                 16.021155593055013,
#                 16.024669014161177,
#                 16.029926616196057,
#                 16.033785875757502])])}

# %%
training_rounds = range(len(eval_result['validation_0']['rmse']))

# %%
print(training_rounds)
# Out:
# range(0, 100)

# %%
plt.scatter(x=training_rounds,y=eval_result['validation_0']['rmse'],label='Training Error')
plt.scatter(x=training_rounds,y=eval_result['validation_1']['rmse'],label='Validation Error')
plt.grid(True)
plt.xlabel('Iterations')
plt.ylabel('RMSE')
plt.title('XGBoost Training Vs Validation Error')
plt.legend()
plt.show()

# %%
xgb.plot_importance(regressor)
plt.show()

# %% [markdown]
# ## Validation Dataset Compare Actual and Predicted

# %%
result = regressor.predict(X_validation)

# %%
result[:5]
# Out:
# array([349.84012 ,  46.383686, 322.29788 , 708.3745  , 567.6732  ],
#       dtype=float32)

# %%
plt.title('XGBoost - Validation Dataset')
plt.scatter(df_validation.x,df_validation.y,label='actual',marker='.')
plt.scatter(df_validation.x,result,label='predicted',marker='.')
plt.grid(True)
plt.legend()
plt.show()

# %%
# RMSE Metrics
print('XGBoost Algorithm Metrics')
mse = mean_squared_error(df_validation.y,result)
print(" Mean Squared Error: {0:.2f}".format(mse))
print(" Root Mean Square Error: {0:.2f}".format(mse**.5))
# Out:
# XGBoost Algorithm Metrics
#  Mean Squared Error: 257.08
#  Root Mean Square Error: 16.03

# %%
# Residual
# Over prediction and Under Prediction needs to be balanced
# Training Data Residuals
residuals = df_validation.y - result
plt.hist(residuals)
plt.grid(True)
plt.xlabel('Actual - Predicted')
plt.ylabel('Count')
plt.title('XGBoost Residual')
plt.axvline(color='r')
plt.show()

# %%
# Count number of values greater than zero and less than zero
value_counts = (residuals > 0).value_counts(sort=False)

print(' Under Estimation: {0}'.format(value_counts[True]))
print(' Over  Estimation: {0}'.format(value_counts[False]))
# Out:
#  Under Estimation: 25
#  Over  Estimation: 20

# %%
# Plot for entire dataset
plt.plot(df.x,df.y,label='Target')
plt.plot(df.x,regressor.predict(df[['x']]) ,label='Predicted')
plt.grid(True)
plt.xlabel('Input Feature')
plt.ylabel('Target')
plt.legend()
plt.title('XGBoost')
plt.show()

# %% [markdown]
# ## Linear Regression Algorithm

# %%
lin_regressor = LinearRegression()

# %%
lin_regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Compare Weights assigned by Linear Regression.
#
# Original Function: 5*x + 8 + some noise

# %%
lin_regressor.coef_
# Out:
# array([4.99777227])

# %%
lin_regressor.intercept_
# Out:
# 8.683965388503225

# %%
result = lin_regressor.predict(df_validation[['x']])

# %%
plt.title('LinearRegression - Validation Dataset')
plt.scatter(df_validation.x,df_validation.y,label='actual',marker='.')
plt.scatter(df_validation.x,result,label='predicted',marker='.')
plt.grid(True)
plt.legend()
plt.show()

# %%
# RMSE Metrics
print('Linear Regression Metrics')
mse = mean_squared_error(df_validation.y,result)
print(" Mean Squared Error: {0:.2f}".format(mse))
print(" Root Mean Square Error: {0:.2f}".format(mse**.5))
# Out:
# Linear Regression Metrics
#  Mean Squared Error: 99.10
#  Root Mean Square Error: 9.95

# %%
# Residual
# Over prediction and Under Prediction needs to be balanced
# Training Data Residuals
residuals = df_validation.y - result
plt.hist(residuals)
plt.grid(True)
plt.xlabel('Actual - Predicted')
plt.ylabel('Count')
plt.title('Linear Regression Residual')
plt.axvline(color='r')
plt.show()

# %%
# Count number of values greater than zero and less than zero
value_counts = (residuals > 0).value_counts(sort=False)

print(' Under Estimation: {0}'.format(value_counts[True]))
print(' Over  Estimation: {0}'.format(value_counts[False]))
# Out:
#  Under Estimation: 24
#  Over  Estimation: 21

# %%
# Plot for entire dataset
plt.plot(df.x,df.y,label='Target')
plt.plot(df.x,lin_regressor.predict(df[['x']]) ,label='Predicted')
plt.grid(True)
plt.xlabel('Input Feature')
plt.ylabel('Target')
plt.legend()
plt.title('LinearRegression')
plt.show()

# %% [markdown]
# <h2>Input Features - Outside range used for training</h2>
#
# XGBoost Prediction has an upper and lower bound (applies to tree based algorithms)
#
# Linear Regression extrapolates

# %%
# True Function
def straight_line(x):
    return 5*x + 8

# %%
# X is outside range of training samples
X = np.array([-100,-5,160,1000,5000])
y = straight_line(X)

df_tmp = pd.DataFrame({'x':X,'y':y})
df_tmp['xgboost']=regressor.predict(df_tmp[['x']])
df_tmp['linear']=lin_regressor.predict(df_tmp[['x']])

# %%
df_tmp
# Out:
#       x      y     xgboost        linear
# 0  -100   -492    9.875030   -491.093262
# 1    -5    -17    9.875030    -16.304896
# 2   160    808  739.915405    808.327528
# 3  1000   5008  739.915405   5006.456235
# 4  5000  25008  739.915405  24997.545312

# %%
# XGBoost Predictions have an upper bound and lower bound
# Linear Regression Extrapolates
plt.scatter(df_tmp.x,df_tmp.y,label='Actual',color='r')
plt.plot(df_tmp.x,df_tmp.linear,label='LinearRegression')
plt.plot(df_tmp.x,df_tmp.xgboost,label='XGBoost')
plt.legend()
plt.xlabel('X')
plt.ylabel('y')
plt.title('Input Outside Range')
plt.show()

# %%
# X is inside range of training samples
X = np.array([0,1,3,5,7,9,11,15,18,125])
y = straight_line(X)

df_tmp = pd.DataFrame({'x':X,'y':y})
df_tmp['xgboost']=regressor.predict(df_tmp[['x']])
df_tmp['linear']=lin_regressor.predict(df_tmp[['x']])

# %%
df_tmp
# Out:
#      x    y     xgboost      linear
# 0    0    8    9.875030    8.683965
# 1    1   13    9.875030   13.681738
# 2    3   23   20.506535   23.677282
# 3    5   33   20.506535   33.672827
# 4    7   43   28.947264   43.668371
# 5    9   53   49.392441   53.663916
# 6   11   63   46.383686   63.659460
# 7   15   83   75.641212   83.650549
# 8   18   98  111.240280   98.643866
# 9  125  633  610.248718  633.405499

# %%
# XGBoost Predictions have an upper bound and lower bound
# Linear Regression Extrapolates
plt.scatter(df_tmp.x,df_tmp.y,label='Actual',color='r')
plt.plot(df_tmp.x,df_tmp.linear,label='LinearRegression')
plt.plot(df_tmp.x,df_tmp.xgboost,label='XGBoost')
plt.legend()
plt.xlabel('X')
plt.ylabel('y')
plt.title('Input within range')
plt.show()

# %% [markdown]
# <h2>Summary</h2>

# %% [markdown]
# 1. Use sagemaker notebook as your own server on the cloud
# 2. Install python packages
# 3. Train directly on SageMaker Notebook (for small datasets, it takes few seconds).
# 4. Once happy with algorithm and performance, you can train on sagemaker cloud (takes several minutes even for small datasets)
# 5. Not all algorithms are available for installation (for example: AWS algorithms like DeepAR are available only in SageMaker)
# 6. In this exercise, we installed XGBoost and compared performance of XGBoost model and Linear Regression
