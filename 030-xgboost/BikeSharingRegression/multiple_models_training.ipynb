# %% [markdown]
# # XGBoost - Two different models
# ### Train bike rental dataset with different hyperparameters
#
# SageMaker SDK Documentation: https://sagemaker.readthedocs.io/en/latest/overview.html

# %%
import numpy as np
import pandas as pd

import boto3
import re

import sagemaker
from sagemaker import get_execution_role
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.0' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml

# %% [markdown]
# ## Upload Data to S3

# %%
# Specify your bucket name
bucket_name = 'sagemaker-us-east-1-190250733572'

training_folder = r'bikerental-hyper/training/'
validation_folder = r'bikerental-hyper/validation/'
test_folder = r'bikerental-hyper/test/'

s3_model_output_location = r's3://{0}/bikerental-hyper/model'.format(bucket_name)
s3_training_file_location = r's3://{0}/{1}'.format(bucket_name,training_folder)
s3_validation_file_location = r's3://{0}/{1}'.format(bucket_name,validation_folder)
s3_test_file_location = r's3://{0}/{1}'.format(bucket_name,test_folder)

# %%
print(s3_model_output_location)
print(s3_training_file_location)
print(s3_validation_file_location)
print(s3_test_file_location)
# Out:
# s3://sagemaker-us-east-1-190250733572/bikerental-hyper/model
# s3://sagemaker-us-east-1-190250733572/bikerental-hyper/training/
# s3://sagemaker-us-east-1-190250733572/bikerental-hyper/validation/
# s3://sagemaker-us-east-1-190250733572/bikerental-hyper/test/

# %%
# Data Channels for the training algorithm
# content type can be libsvm or csv for XGBoost
training_input_config = sagemaker.session.TrainingInput(
    s3_data=s3_training_file_location,
    content_type='csv',
    s3_data_type='S3Prefix')

validation_input_config = sagemaker.session.TrainingInput(
    s3_data=s3_validation_file_location,
    content_type='csv',
    s3_data_type='S3Prefix'
)

data_channels = {'train': training_input_config, 'validation': validation_input_config}

# %%
# Write and Reading from S3 is just as easy
# files are referred as objects in S3.  
# file name is referred as key name in S3

# File stored in S3 is automatically replicated across 3 different availability zones 
# in the region where the bucket was created.

# http://boto3.readthedocs.io/en/latest/guide/s3.html
def write_to_s3(filename, bucket, key):
    with open(filename,'rb') as f: # Read in binary mode
        return boto3.Session().resource('s3').Bucket(bucket).Object(key).upload_fileobj(f)

# %%
write_to_s3('bike_train.csv', 
            bucket_name,
            training_folder + 'bike_train.csv')

write_to_s3('bike_validation.csv',
            bucket_name,
            validation_folder + 'bike_validation.csv')

write_to_s3('bike_test.csv',
            bucket_name,
            test_folder + 'bike_test.csv')

# %% [markdown]
# ## Training Algorithm Docker Image
# ### SageMaker maintains a separate image for algorithm and region
# https://docs.aws.amazon.com/sagemaker/latest/dg/sagemaker-algo-docker-registry-paths.html

# %%
# Use Spot Instance - Save up to 90% of training cost by using spot instances when compared to on-demand instances
# Reference: https://github.com/aws-samples/amazon-sagemaker-managed-spot-training/blob/main/xgboost_built_in_managed_spot_training_checkpointing/xgboost_built_in_managed_spot_training_checkpointing.ipynb

# if you are still on two-month free-tier you can use the on-demand instance by setting:
#   use_spot_instances = False

# We will use spot for training
use_spot_instances = True
max_run = 3600 # in seconds
max_wait = 7200 if use_spot_instances else None # in seconds

# %%
def fit_model(jobSuffix, hyperParameters):
    # Establish a session with AWS
    sess = sagemaker.Session()
    # This role contains the permissions needed to train, deploy models    
    role = get_execution_role()
    
    # job name has the version details - replace "." with "-"
    job_name = f"xgboost-bikerental-{jobSuffix}"
    
    print (f"***Job name: {job_name}***")
    
    checkpoint_s3_uri = None

    if use_spot_instances:
        checkpoint_s3_uri = f's3://{bucket_name}/bikerental-hyper/checkpoints/{job_name}'

    print (f'Checkpoint uri: {checkpoint_s3_uri}')
            
    # Use the specified version of XGBoost
    container = sagemaker.image_uris.retrieve("xgboost",
                                              sess.boto_region_name,
                                              version="1.2-2")

    print (f'Using XGBoost Container {container}')
    
    # Configure the training job
    # for managed spot training, specify the use_spot_instances flag, max_run, max_wait and checkpoint_s3_uri
    estimator = sagemaker.estimator.Estimator(
        container,
        role,
        instance_count=1,
        instance_type='ml.m5.xlarge',
        output_path=s3_model_output_location,
        sagemaker_session=sess,
        base_job_name = job_name,
        hyperparameters = hyperParameters,
        use_spot_instances=use_spot_instances,
        max_run=max_run,
        max_wait=max_wait,
        checkpoint_s3_uri=checkpoint_s3_uri)

    estimator.fit(data_channels)

    return estimator.latest_training_job.name

# %%
# XGBoost hyperparameters
hyperParametersOne = {"objective":"reg:squarederror",                   
                      "eta":0.1,
                      "max_depth":5,
                      "num_round":150}

# Adjust depth and round
hyperParametersTwo = {"objective":"reg:squarederror",
                      "eta":0.1,
                      "max_depth":7,
                      "num_round":200}

# %%
fit_model(jobSuffix="hyper-one", hyperParameters=hyperParametersOne)
# Out:
# INFO:sagemaker:Creating training-job with name: xgboost-bikerental-hyper-one-2024-01-01-20-42-23-609
# ***Job name: xgboost-bikerental-hyper-one***
# Checkpoint uri: s3://sagemaker-us-east-1-190250733572/bikerental-hyper/checkpoints/xgboost-bikerental-hyper-one
# Using XGBoost Container 683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-xgboost:1.2-2
# 2024-01-01 20:42:23 Starting - Starting the training job...
# 2024-01-01 20:42:37 Starting - Preparing the instances for training......
# 2024-01-01 20:43:45 Downloading - Downloading input data...
# 2024-01-01 20:44:15 Downloading - Downloading the training image...
# 2024-01-01 20:44:46 Training - Training image download completed. Training in progress..[2024-01-01 20:44:54.255 ip-10-2-239-212.ec2.internal:7 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2024-01-01:20:44:54:INFO] Imported framework sagemaker_xgboost_container.training
# [2024-01-01:20:44:54:INFO] Failed to parse hyperparameter objective value reg:squarederror to Json.
# Returning the value itself
# [2024-01-01:20:44:54:INFO] No GPUs detected (normal if no gpus installed)
# [2024-01-01:20:44:54:INFO] Running XGBoost Sagemaker in algorithm mode
# [2024-01-01:20:44:54:INFO] Determined delimiter of CSV input is ','
# [2024-01-01:20:44:54:INFO] Determined delimiter of CSV input is ','
# [2024-01-01:20:44:54:INFO] Determined delimiter of CSV input is ','
# [2024-01-01:20:44:54:INFO] Determined delimiter of CSV input is ','
# [2024-01-01:20:44:54:INFO] Single node training.
# [2024-01-01:20:44:54:INFO] Train matrix has 7620 rows and 13 columns
# [2024-01-01:20:44:54:INFO] Validation matrix has 3266 rows
# [2024-01-01 20:44:54.342 ip-10-2-239-212.ec2.internal:7 INFO json_config.py:91] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2024-01-01 20:44:54.342 ip-10-2-239-212.ec2.internal:7 INFO hook.py:201] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2024-01-01 20:44:54.343 ip-10-2-239-212.ec2.internal:7 INFO profiler_config_parser.py:102] User has disabled profiler.
# [2024-01-01 20:44:54.343 ip-10-2-239-212.ec2.internal:7 INFO hook.py:255] Saving to /opt/ml/output/tensors
# [2024-01-01:20:44:54:INFO] Debug hook created from config
# [0]#011train-rmse:242.02477#011validation-rmse:240.47899
# [2024-01-01 20:44:54.350 ip-10-2-239-212.ec2.internal:7 INFO hook.py:423] Monitoring the collections: metrics
# [2024-01-01 20:44:54.353 ip-10-2-239-212.ec2.internal:7 INFO hook.py:486] Hook is writing from the hook with pid: 7
# [1]#011train-rmse:222.81418#011validation-rmse:221.17284
# [2]#011train-rmse:205.57568#011validation-rmse:204.06339
# [3]#011train-rmse:190.46678#011validation-rmse:188.93123
# [4]#011train-rmse:177.23645#011validation-rmse:175.82954
# [5]#011train-rmse:165.79686#011validation-rmse:164.38275
# [6]#011train-rmse:155.56654#011validation-rmse:154.23116
# [7]#011train-rmse:146.62457#011validation-rmse:145.38609
# [8]#011train-rmse:138.65471#011validation-rmse:137.59018
# [9]#011train-rmse:131.49017#011validation-rmse:130.62087
# [10]#011train-rmse:125.39840#011validation-rmse:124.68773
# [11]#011train-rmse:118.57058#011validation-rmse:118.20283
# [12]#011train-rmse:112.71213#011validation-rmse:112.61279
# [13]#011train-rmse:105.46042#011validation-rmse:105.86491
# [14]#011train-rmse:101.20928#011validation-rmse:101.79639
# [15]#011train-rmse:97.05930#011validation-rmse:97.91491
# [16]#011train-rmse:91.92148#011validation-rmse:93.06421
# [17]#011train-rmse:89.17197#011validation-rmse:90.36886
# [18]#011train-rmse:86.75575#011validation-rmse:88.09059
# [19]#011train-rmse:82.94788#011validation-rmse:84.52699
# [20]#011train-rmse:80.81974#011validation-rmse:82.61877
# [21]#011train-rmse:78.69159#011validation-rmse:80.70377
# [22]#011train-rmse:76.53494#011validation-rmse:78.66435
# [23]#011train-rmse:72.73273#011validation-rmse:75.20918
# [24]#011train-rmse:70.72641#011validation-rmse:73.37030
# [25]#011train-rmse:67.98768#011validation-rmse:70.99341
# [26]#011train-rmse:66.77643#011validation-rmse:69.85777
# [27]#011train-rmse:64.72002#011validation-rmse:67.94609
# [28]#011train-rmse:63.88744#011validation-rmse:67.16691
# [29]#011train-rmse:62.65825#011validation-rmse:66.07320
# [30]#011train-rmse:61.94872#011validation-rmse:65.41085
# [31]#011train-rmse:61.05209#011validation-rmse:64.66998
# [32]#011train-rmse:59.85604#011validation-rmse:63.62014
# [33]#011train-rmse:59.35921#011validation-rmse:63.17416
# [34]#011train-rmse:58.66875#011validation-rmse:62.51107
# [35]#011train-rmse:56.97491#011validation-rmse:60.97248
# [36]#011train-rmse:56.39343#011validation-rmse:60.43429
# [37]#011train-rmse:55.71895#011validation-rmse:59.80642
# [38]#011train-rmse:55.35701#011validation-rmse:59.58389
# [39]#011train-rmse:53.93565#011validation-rmse:58.35087
# [40]#011train-rmse:53.50989#011validation-rmse:57.99298
# [41]#011train-rmse:52.83466#011validation-rmse:57.41309
# [42]#011train-rmse:52.42664#011validation-rmse:57.05108
# [43]#011train-rmse:51.91262#011validation-rmse:56.62519
# [44]#011train-rmse:51.64758#011validation-rmse:56.39834
# [45]#011train-rmse:51.34618#011validation-rmse:56.16906
# [46]#011train-rmse:50.33508#011validation-rmse:55.32206
# [47]#011train-rmse:50.15849#011validation-rmse:55.17595
# [48]#011train-rmse:49.77798#011validation-rmse:54.87716
# [49]#011train-rmse:49.58944#011validation-rmse:54.72893
# [50]#011train-rmse:49.25811#011validation-rmse:54.47450
# [51]#011train-rmse:48.33059#011validation-rmse:53.59128
# [52]#011train-rmse:47.90930#011validation-rmse:53.21664
# [53]#011train-rmse:47.69841#011validation-rmse:53.07549
# [54]#011train-rmse:47.45998#011validation-rmse:52.94033
# [55]#011train-rmse:47.25755#011validation-rmse:52.80841
# [56]#011train-rmse:46.63244#011validation-rmse:52.29823
# [57]#011train-rmse:46.42562#011validation-rmse:52.16420
# [58]#011train-rmse:46.24618#011validation-rmse:52.02133
# [59]#011train-rmse:46.11836#011validation-rmse:51.92621
# [60]#011train-rmse:45.64040#011validation-rmse:51.53408
# [61]#011train-rmse:45.44554#011validation-rmse:51.37811
# [62]#011train-rmse:45.26523#011validation-rmse:51.25235
# [63]#011train-rmse:45.17466#011validation-rmse:51.16955
# [64]#011train-rmse:44.46129#011validation-rmse:50.53622
# [65]#011train-rmse:44.31697#011validation-rmse:50.43384
# [66]#011train-rmse:43.91795#011validation-rmse:50.03748
# [67]#011train-rmse:43.80186#011validation-rmse:49.98050
# [68]#011train-rmse:43.62652#011validation-rmse:49.85042
# [69]#011train-rmse:43.49795#011validation-rmse:49.73853
# [70]#011train-rmse:43.40588#011validation-rmse:49.67141
# [71]#011train-rmse:43.28690#011validation-rmse:49.59452
# [72]#011train-rmse:43.21510#011validation-rmse:49.53452
# [73]#011train-rmse:43.09950#011validation-rmse:49.46745
# [74]#011train-rmse:42.95085#011validation-rmse:49.37531
# [75]#011train-rmse:42.31794#011validation-rmse:48.87185
# [76]#011train-rmse:42.19750#011validation-rmse:48.77583
# [77]#011train-rmse:41.72556#011validation-rmse:48.33872
# [78]#011train-rmse:41.64749#011validation-rmse:48.24890
# [79]#011train-rmse:41.56053#011validation-rmse:48.21305
# [80]#011train-rmse:41.40102#011validation-rmse:48.08414
# [81]#011train-rmse:41.30600#011validation-rmse:48.02918
# [82]#011train-rmse:41.10287#011validation-rmse:47.88898
# [83]#011train-rmse:41.00995#011validation-rmse:47.83494
# [84]#011train-rmse:40.85508#011validation-rmse:47.79559
# [85]#011train-rmse:40.72648#011validation-rmse:47.71399
# [86]#011train-rmse:40.40880#011validation-rmse:47.42501
# [87]#011train-rmse:40.35090#011validation-rmse:47.40135
# [88]#011train-rmse:40.27492#011validation-rmse:47.36775
# [89]#011train-rmse:39.87699#011validation-rmse:47.07705
# [90]#011train-rmse:39.78273#011validation-rmse:47.00270
# [91]#011train-rmse:39.75341#011validation-rmse:46.97659
# [92]#011train-rmse:39.32650#011validation-rmse:46.64780
# [93]#011train-rmse:39.27236#011validation-rmse:46.62083
# [94]#011train-rmse:39.22442#011validation-rmse:46.62555
# [95]#011train-rmse:39.16849#011validation-rmse:46.58261
# [96]#011train-rmse:39.01161#011validation-rmse:46.46513
# [97]#011train-rmse:38.78480#011validation-rmse:46.28094
# [98]#011train-rmse:38.68225#011validation-rmse:46.21397
# [99]#011train-rmse:38.45327#011validation-rmse:46.04032
# [100]#011train-rmse:38.41620#011validation-rmse:46.03463
# [101]#011train-rmse:38.34577#011validation-rmse:46.01743
# [102]#011train-rmse:38.15730#011validation-rmse:45.85439
# [103]#011train-rmse:38.04013#011validation-rmse:45.80592
# [104]#011train-rmse:37.88230#011validation-rmse:45.71357
# [105]#011train-rmse:37.73215#011validation-rmse:45.61249
# [106]#011train-rmse:37.57912#011validation-rmse:45.55039
# [107]#011train-rmse:37.54836#011validation-rmse:45.52543
# [108]#011train-rmse:37.45421#011validation-rmse:45.45245
# [109]#011train-rmse:37.28855#011validation-rmse:45.37426
# [110]#011train-rmse:37.21427#011validation-rmse:45.32071
# [111]#011train-rmse:37.13742#011validation-rmse:45.28488
# [112]#011train-rmse:37.05065#011validation-rmse:45.21874
# [113]#011train-rmse:36.82139#011validation-rmse:45.01421
# [114]#011train-rmse:36.73454#011validation-rmse:44.95208
# [115]#011train-rmse:36.66826#011validation-rmse:44.89340
# [116]#011train-rmse:36.56608#011validation-rmse:44.85519
# [117]#011train-rmse:36.41806#011validation-rmse:44.73439
# [118]#011train-rmse:36.33566#011validation-rmse:44.71035
# [119]#011train-rmse:36.20802#011validation-rmse:44.69101
# [120]#011train-rmse:36.14981#011validation-rmse:44.65616
# [121]#011train-rmse:36.12365#011validation-rmse:44.63966
# [122]#011train-rmse:36.01445#011validation-rmse:44.58714
# [123]#011train-rmse:35.96537#011validation-rmse:44.51946
# [124]#011train-rmse:35.91959#011validation-rmse:44.48346
# [125]#011train-rmse:35.90220#011validation-rmse:44.47380
# [126]#011train-rmse:35.81009#011validation-rmse:44.44931
# [127]#011train-rmse:35.72566#011validation-rmse:44.38972
# [128]#011train-rmse:35.60253#011validation-rmse:44.34499
# [129]#011train-rmse:35.56325#011validation-rmse:44.31740
# [130]#011train-rmse:35.48661#011validation-rmse:44.30695
# [131]#011train-rmse:35.40610#011validation-rmse:44.23590
# [132]#011train-rmse:35.35366#011validation-rmse:44.20710
# [133]#011train-rmse:35.31818#011validation-rmse:44.20804
# [134]#011train-rmse:35.27993#011validation-rmse:44.19393
# [135]#011train-rmse:35.25702#011validation-rmse:44.18780
# [136]#011train-rmse:35.21952#011validation-rmse:44.17223
# [137]#011train-rmse:35.16722#011validation-rmse:44.13706
# [138]#011train-rmse:35.09853#011validation-rmse:44.09353
# [139]#011train-rmse:35.06233#011validation-rmse:44.05856
# [140]#011train-rmse:35.04578#011validation-rmse:44.05186
# [141]#011train-rmse:35.03037#011validation-rmse:44.04196
# [142]#011train-rmse:34.96915#011validation-rmse:44.02687
# [143]#011train-rmse:34.93986#011validation-rmse:44.00234
# [144]#011train-rmse:34.89653#011validation-rmse:43.95389
# [145]#011train-rmse:34.84055#011validation-rmse:43.94776
# [146]#011train-rmse:34.73851#011validation-rmse:43.89673
# [147]#011train-rmse:34.71177#011validation-rmse:43.88660
# [148]#011train-rmse:34.64078#011validation-rmse:43.87335
# [149]#011train-rmse:34.52586#011validation-rmse:43.80913
#
# 2024-01-01 20:45:12 Uploading - Uploading generated training model
# 2024-01-01 20:45:12 Completed - Training job completed
# Training seconds: 87
# Billable seconds: 35
# Managed Spot Training savings: 59.8%
# 'xgboost-bikerental-hyper-one-2024-01-01-20-42-23-609'

# %%
fit_model(jobSuffix="hyper-two", hyperParameters=hyperParametersTwo)
# Out:
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.
# INFO:sagemaker:Creating training-job with name: xgboost-bikerental-hyper-two-2024-01-01-20-45-36-378
# ***Job name: xgboost-bikerental-hyper-two***
# Checkpoint uri: s3://sagemaker-us-east-1-190250733572/bikerental-hyper/checkpoints/xgboost-bikerental-hyper-two
# Using XGBoost Container 683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-xgboost:1.2-2
# 2024-01-01 20:45:36 Starting - Starting the training job...
# 2024-01-01 20:45:52 Starting - Preparing the instances for training......
# 2024-01-01 20:47:02 Downloading - Downloading input data...
# 2024-01-01 20:47:28 Downloading - Downloading the training image...
# 2024-01-01 20:48:03 Training - Training image download completed. Training in progress...[2024-01-01 20:48:14.706 ip-10-2-200-223.ec2.internal:7 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2024-01-01:20:48:14:INFO] Imported framework sagemaker_xgboost_container.training
# [2024-01-01:20:48:14:INFO] Failed to parse hyperparameter objective value reg:squarederror to Json.
# Returning the value itself
# [2024-01-01:20:48:14:INFO] No GPUs detected (normal if no gpus installed)
# [2024-01-01:20:48:14:INFO] Running XGBoost Sagemaker in algorithm mode
# [2024-01-01:20:48:14:INFO] Determined delimiter of CSV input is ','
# [2024-01-01:20:48:14:INFO] Determined delimiter of CSV input is ','
# [2024-01-01:20:48:14:INFO] Determined delimiter of CSV input is ','
# [2024-01-01:20:48:14:INFO] Determined delimiter of CSV input is ','
# [2024-01-01:20:48:14:INFO] Single node training.
# [2024-01-01:20:48:14:INFO] Train matrix has 7620 rows and 13 columns
# [2024-01-01:20:48:14:INFO] Validation matrix has 3266 rows
# [2024-01-01 20:48:14.796 ip-10-2-200-223.ec2.internal:7 INFO json_config.py:91] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2024-01-01 20:48:14.796 ip-10-2-200-223.ec2.internal:7 INFO hook.py:201] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2024-01-01 20:48:14.796 ip-10-2-200-223.ec2.internal:7 INFO profiler_config_parser.py:102] User has disabled profiler.
# [2024-01-01 20:48:14.797 ip-10-2-200-223.ec2.internal:7 INFO hook.py:255] Saving to /opt/ml/output/tensors
# [2024-01-01:20:48:14:INFO] Debug hook created from config
# [0]#011train-rmse:240.37886#011validation-rmse:239.03227
# [2024-01-01 20:48:14.806 ip-10-2-200-223.ec2.internal:7 INFO hook.py:423] Monitoring the collections: metrics
# [2024-01-01 20:48:14.808 ip-10-2-200-223.ec2.internal:7 INFO hook.py:486] Hook is writing from the hook with pid: 7
# [1]#011train-rmse:219.48474#011validation-rmse:218.34473
# [2]#011train-rmse:200.79140#011validation-rmse:199.96027
# [3]#011train-rmse:184.25200#011validation-rmse:183.46341
# [4]#011train-rmse:169.44132#011validation-rmse:168.81229
# [5]#011train-rmse:156.24309#011validation-rmse:155.71085
# [6]#011train-rmse:144.50125#011validation-rmse:144.21339
# [7]#011train-rmse:134.09697#011validation-rmse:134.23146
# [8]#011train-rmse:123.49555#011validation-rmse:124.05136
# [9]#011train-rmse:114.35129#011validation-rmse:115.17657
# [10]#011train-rmse:106.06701#011validation-rmse:107.18615
# [11]#011train-rmse:98.63186#011validation-rmse:100.14427
# [12]#011train-rmse:92.13759#011validation-rmse:93.94878
# [13]#011train-rmse:86.09508#011validation-rmse:88.22766
# [14]#011train-rmse:80.86150#011validation-rmse:83.36149
# [15]#011train-rmse:76.14858#011validation-rmse:78.94219
# [16]#011train-rmse:71.92284#011validation-rmse:75.09288
# [17]#011train-rmse:68.45921#011validation-rmse:71.91588
# [18]#011train-rmse:65.25536#011validation-rmse:69.01778
# [19]#011train-rmse:62.55600#011validation-rmse:66.62283
# [20]#011train-rmse:60.26503#011validation-rmse:64.56912
# [21]#011train-rmse:58.04637#011validation-rmse:62.68779
# [22]#011train-rmse:54.91629#011validation-rmse:60.01759
# [23]#011train-rmse:52.20663#011validation-rmse:57.74981
# [24]#011train-rmse:49.84087#011validation-rmse:55.79822
# [25]#011train-rmse:47.69623#011validation-rmse:54.10582
# [26]#011train-rmse:45.70204#011validation-rmse:52.53263
# [27]#011train-rmse:44.13290#011validation-rmse:51.30822
# [28]#011train-rmse:42.69581#011validation-rmse:50.15542
# [29]#011train-rmse:41.37008#011validation-rmse:49.13169
# [30]#011train-rmse:40.30407#011validation-rmse:48.33912
# [31]#011train-rmse:39.34811#011validation-rmse:47.60539
# [32]#011train-rmse:38.58145#011validation-rmse:47.02061
# [33]#011train-rmse:37.74600#011validation-rmse:46.38480
# [34]#011train-rmse:37.14364#011validation-rmse:45.94897
# [35]#011train-rmse:36.61488#011validation-rmse:45.51432
# [36]#011train-rmse:35.80374#011validation-rmse:45.00383
# [37]#011train-rmse:35.14220#011validation-rmse:44.58030
# [38]#011train-rmse:34.66100#011validation-rmse:44.30845
# [39]#011train-rmse:34.21651#011validation-rmse:44.04240
# [40]#011train-rmse:33.82784#011validation-rmse:43.77341
# [41]#011train-rmse:33.56519#011validation-rmse:43.61297
# [42]#011train-rmse:33.13685#011validation-rmse:43.31770
# [43]#011train-rmse:32.76014#011validation-rmse:43.11432
# [44]#011train-rmse:32.08776#011validation-rmse:42.72162
# [45]#011train-rmse:31.84914#011validation-rmse:42.60810
# [46]#011train-rmse:31.60347#011validation-rmse:42.49632
# [47]#011train-rmse:31.06541#011validation-rmse:42.23161
# [48]#011train-rmse:30.75756#011validation-rmse:42.04844
# [49]#011train-rmse:30.51457#011validation-rmse:41.91620
# [50]#011train-rmse:30.34845#011validation-rmse:41.84994
# [51]#011train-rmse:30.16390#011validation-rmse:41.80450
# [52]#011train-rmse:29.65100#011validation-rmse:41.58677
# [53]#011train-rmse:29.38422#011validation-rmse:41.47401
# [54]#011train-rmse:29.05632#011validation-rmse:41.32060
# [55]#011train-rmse:28.81535#011validation-rmse:41.24410
# [56]#011train-rmse:28.70984#011validation-rmse:41.18972
# [57]#011train-rmse:28.53901#011validation-rmse:41.10759
# [58]#011train-rmse:28.26591#011validation-rmse:40.97854
# [59]#011train-rmse:28.13097#011validation-rmse:40.93149
# [60]#011train-rmse:27.93823#011validation-rmse:40.77719
# [61]#011train-rmse:27.71436#011validation-rmse:40.66789
# [62]#011train-rmse:27.49916#011validation-rmse:40.57786
# [63]#011train-rmse:27.42209#011validation-rmse:40.53899
# [64]#011train-rmse:27.18259#011validation-rmse:40.37924
# [65]#011train-rmse:27.08688#011validation-rmse:40.31950
# [66]#011train-rmse:26.97867#011validation-rmse:40.30452
# [67]#011train-rmse:26.85290#011validation-rmse:40.27115
# [68]#011train-rmse:26.75669#011validation-rmse:40.17487
# [69]#011train-rmse:26.63229#011validation-rmse:40.11946
# [70]#011train-rmse:26.43825#011validation-rmse:40.03429
# [71]#011train-rmse:26.38448#011validation-rmse:40.02807
# [72]#011train-rmse:26.16049#011validation-rmse:39.95506
# [73]#011train-rmse:26.12778#011validation-rmse:39.93866
# [74]#011train-rmse:25.91012#011validation-rmse:39.87697
# [75]#011train-rmse:25.87050#011validation-rmse:39.87229
# [76]#011train-rmse:25.68213#011validation-rmse:39.78692
# [77]#011train-rmse:25.62490#011validation-rmse:39.75842
# [78]#011train-rmse:25.55476#011validation-rmse:39.74109
# [79]#011train-rmse:25.38723#011validation-rmse:39.67059
# [80]#011train-rmse:25.28535#011validation-rmse:39.62238
# [81]#011train-rmse:25.12803#011validation-rmse:39.55198
# [82]#011train-rmse:24.98560#011validation-rmse:39.51773
# [83]#011train-rmse:24.90107#011validation-rmse:39.46486
# [84]#011train-rmse:24.80953#011validation-rmse:39.41983
# [85]#011train-rmse:24.78542#011validation-rmse:39.41340
# [86]#011train-rmse:24.69863#011validation-rmse:39.37847
# [87]#011train-rmse:24.65686#011validation-rmse:39.37262
# [88]#011train-rmse:24.43943#011validation-rmse:39.31218
# [89]#011train-rmse:24.23997#011validation-rmse:39.24169
# [90]#011train-rmse:24.14010#011validation-rmse:39.21270
# [91]#011train-rmse:24.10006#011validation-rmse:39.20562
# [92]#011train-rmse:23.99160#011validation-rmse:39.20117
# [93]#011train-rmse:23.95756#011validation-rmse:39.19621
# [94]#011train-rmse:23.83808#011validation-rmse:39.17836
# [95]#011train-rmse:23.76141#011validation-rmse:39.14797
# [96]#011train-rmse:23.66111#011validation-rmse:39.10300
# [97]#011train-rmse:23.55565#011validation-rmse:39.08555
# [98]#011train-rmse:23.35452#011validation-rmse:39.04308
# [99]#011train-rmse:23.18228#011validation-rmse:39.01254
# [100]#011train-rmse:23.11530#011validation-rmse:38.99099
# [101]#011train-rmse:23.01048#011validation-rmse:38.97021
# [102]#011train-rmse:22.98083#011validation-rmse:38.96751
# [103]#011train-rmse:22.82393#011validation-rmse:38.96793
# [104]#011train-rmse:22.73185#011validation-rmse:38.93778
# [105]#011train-rmse:22.68080#011validation-rmse:38.92020
# [106]#011train-rmse:22.58141#011validation-rmse:38.89086
# [107]#011train-rmse:22.47904#011validation-rmse:38.86865
# [108]#011train-rmse:22.32504#011validation-rmse:38.84832
# [109]#011train-rmse:22.27332#011validation-rmse:38.83350
# [110]#011train-rmse:22.09150#011validation-rmse:38.81703
# [111]#011train-rmse:22.00500#011validation-rmse:38.78207
# [112]#011train-rmse:21.96866#011validation-rmse:38.77438
# [113]#011train-rmse:21.94142#011validation-rmse:38.77343
# [114]#011train-rmse:21.92157#011validation-rmse:38.76939
# [115]#011train-rmse:21.79954#011validation-rmse:38.79310
# [116]#011train-rmse:21.59029#011validation-rmse:38.73092
# [117]#011train-rmse:21.48353#011validation-rmse:38.71107
# [118]#011train-rmse:21.45884#011validation-rmse:38.70921
# [119]#011train-rmse:21.39783#011validation-rmse:38.70264
# [120]#011train-rmse:21.32862#011validation-rmse:38.69227
# [121]#011train-rmse:21.31881#011validation-rmse:38.68901
# [122]#011train-rmse:21.28712#011validation-rmse:38.68328
# [123]#011train-rmse:21.26434#011validation-rmse:38.68214
# [124]#011train-rmse:21.23252#011validation-rmse:38.67284
# [125]#011train-rmse:21.18260#011validation-rmse:38.66529
# [126]#011train-rmse:21.14580#011validation-rmse:38.65298
# [127]#011train-rmse:21.03866#011validation-rmse:38.64013
# [128]#011train-rmse:20.94905#011validation-rmse:38.64311
# [129]#011train-rmse:20.90312#011validation-rmse:38.64988
# [130]#011train-rmse:20.82413#011validation-rmse:38.62689
# [131]#011train-rmse:20.77632#011validation-rmse:38.61893
# [132]#011train-rmse:20.68395#011validation-rmse:38.57972
# [133]#011train-rmse:20.62220#011validation-rmse:38.57202
# [134]#011train-rmse:20.52859#011validation-rmse:38.55240
# [135]#011train-rmse:20.45973#011validation-rmse:38.56166
# [136]#011train-rmse:20.44786#011validation-rmse:38.55564
# [137]#011train-rmse:20.41578#011validation-rmse:38.53778
# [138]#011train-rmse:20.37656#011validation-rmse:38.54380
# [139]#011train-rmse:20.22461#011validation-rmse:38.53812
# [140]#011train-rmse:20.07260#011validation-rmse:38.52814
# [141]#011train-rmse:20.01302#011validation-rmse:38.54108
# [142]#011train-rmse:19.84733#011validation-rmse:38.50989
# [143]#011train-rmse:19.73812#011validation-rmse:38.51323
# [144]#011train-rmse:19.66517#011validation-rmse:38.51125
# [145]#011train-rmse:19.54129#011validation-rmse:38.48459
# [146]#011train-rmse:19.47995#011validation-rmse:38.47132
# [147]#011train-rmse:19.35797#011validation-rmse:38.46077
# [148]#011train-rmse:19.30444#011validation-rmse:38.47069
# [149]#011train-rmse:19.26225#011validation-rmse:38.46553
# [150]#011train-rmse:19.20921#011validation-rmse:38.47574
# [151]#011train-rmse:19.09304#011validation-rmse:38.45011
# [152]#011train-rmse:19.00799#011validation-rmse:38.42641
# [153]#011train-rmse:18.98248#011validation-rmse:38.41481
# [154]#011train-rmse:18.92223#011validation-rmse:38.39769
# [155]#011train-rmse:18.78158#011validation-rmse:38.38174
# [156]#011train-rmse:18.71414#011validation-rmse:38.39186
# [157]#011train-rmse:18.69544#011validation-rmse:38.39199
# [158]#011train-rmse:18.68753#011validation-rmse:38.39130
# [159]#011train-rmse:18.67082#011validation-rmse:38.39867
# [160]#011train-rmse:18.66309#011validation-rmse:38.39713
# [161]#011train-rmse:18.57441#011validation-rmse:38.39739
# [162]#011train-rmse:18.56714#011validation-rmse:38.39827
# [163]#011train-rmse:18.48242#011validation-rmse:38.36187
# [164]#011train-rmse:18.38375#011validation-rmse:38.35856
# [165]#011train-rmse:18.26546#011validation-rmse:38.35388
# [166]#011train-rmse:18.25818#011validation-rmse:38.34978
# [167]#011train-rmse:18.14728#011validation-rmse:38.30609
# [168]#011train-rmse:18.14057#011validation-rmse:38.30610
# [169]#011train-rmse:18.13549#011validation-rmse:38.30609
# [170]#011train-rmse:18.02943#011validation-rmse:38.28364
# [171]#011train-rmse:18.02361#011validation-rmse:38.28380
# [172]#011train-rmse:17.99432#011validation-rmse:38.26759
# [173]#011train-rmse:17.90548#011validation-rmse:38.25526
# [174]#011train-rmse:17.79438#011validation-rmse:38.20209
# [175]#011train-rmse:17.70243#011validation-rmse:38.20596
# [176]#011train-rmse:17.67420#011validation-rmse:38.19503
# [177]#011train-rmse:17.54104#011validation-rmse:38.18386
# [178]#011train-rmse:17.50751#011validation-rmse:38.18106
# [179]#011train-rmse:17.42242#011validation-rmse:38.17782
# [180]#011train-rmse:17.40864#011validation-rmse:38.18389
# [181]#011train-rmse:17.33722#011validation-rmse:38.18472
# [182]#011train-rmse:17.32554#011validation-rmse:38.18706
# [183]#011train-rmse:17.31219#011validation-rmse:38.18224
# [184]#011train-rmse:17.23281#011validation-rmse:38.18394
# [185]#011train-rmse:17.16231#011validation-rmse:38.17780
# [186]#011train-rmse:17.15597#011validation-rmse:38.17725
# [187]#011train-rmse:17.09259#011validation-rmse:38.17448
# [188]#011train-rmse:17.03233#011validation-rmse:38.16246
# [189]#011train-rmse:16.98059#011validation-rmse:38.16373
# [190]#011train-rmse:16.92962#011validation-rmse:38.15824
# [191]#011train-rmse:16.85332#011validation-rmse:38.15645
# [192]#011train-rmse:16.82311#011validation-rmse:38.14912
# [193]#011train-rmse:16.76691#011validation-rmse:38.13588
# [194]#011train-rmse:16.71231#011validation-rmse:38.13864
# [195]#011train-rmse:16.63062#011validation-rmse:38.12902
# [196]#011train-rmse:16.57796#011validation-rmse:38.12457
# [197]#011train-rmse:16.53756#011validation-rmse:38.12178
# [198]#011train-rmse:16.49438#011validation-rmse:38.11415
# [199]#011train-rmse:16.45080#011validation-rmse:38.10581
#
# 2024-01-01 20:48:34 Uploading - Uploading generated training model
# 2024-01-01 20:48:34 Completed - Training job completed
# Training seconds: 92
# Billable seconds: 37
# Managed Spot Training savings: 59.8%
# 'xgboost-bikerental-hyper-two-2024-01-01-20-45-36-378'
